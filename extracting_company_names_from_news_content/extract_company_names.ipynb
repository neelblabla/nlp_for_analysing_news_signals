# %%
import pandas as pd
import numpy as np
import warnings

# %%
from google.colab import drive
drive.mount('/content/gdrive')

raw_df=pd.read_csv('/content/gdrive/MyDrive/FS-Sem3/CompanyProject_RegHub/raw_data_competitor_monitoring.csv')
print(f"Length of raw dataframe = {len(raw_df)}")
raw_df.head(2)
# Out:
# Mounted at /content/gdrive
# Length of raw dataframe = 4771
#                               _id           _index  _score _type concepts  \
# 0  FinenfreiPresostenfrei12884764  2021_reghub_new     NaN  _doc      NaN
# 1    focScholzPresid217207826html  2021_reghub_new     NaN  _doc      NaN
#
#   found_dates                              id internal_links keywords  \
# 0          []  FinenfreiPresostenfrei12884764             []      NaN
# 1          []    focScholzPresid217207826html             []      NaN
#
#   language  ...                                       news_summary  \
# 0       de  ...  The article discusses how a fortunate man with...
# 1       en  ...  The article discusses how M.M. Warburg may hav...
#
#                                           news_title  \
# 0  Tradingaktion mit comdirect  Handeln Sie Socié...
# 1  CumExAffäre: Brisante Tagebucheinträge belaste...
#
#                                           news_topic       news_type  \
# 0  [{"description":"Online Banken und Vermögensve...  Press releases
# 1  [{"description":"M.M. Warburg","relevance":12,...  Press releases
#
#    references  sentiment_label sentiment_score  source_country   source_name  \
# 0          []              NaN             0.0         Germany  Finanzen.net
# 1          []              NaN             0.0          Global      focus.de
#
#             source_type
# 0  Information Provider
# 1  Information Provider
#
# [2 rows x 28 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4771 entries, 0 to 4770
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   _id                4771 non-null   object
#  1   _index             4771 non-null   object
#  2   _score             0 non-null      float64
#  3   _type              4771 non-null   object
#  4   concepts           251 non-null    object
#  5   found_dates        4268 non-null   object
#  6   id                 4771 non-null   object
#  7   internal_links     4220 non-null   object
#  8   keywords           251 non-null    object
#  9   language           4768 non-null   object
#  10  news_author        85 non-null     object
#  11  news_content       4771 non-null   object
#  12  news_date          4771 non-null   object
#  13  news_label         199 non-null    object
#  14  news_last_updated  0 non-null      float64
#  15  news_legalinforce  4771 non-null   bool
#  16  news_link          4771 non-null   object
#  17  news_rank          4771 non-null   int64
#  18  news_summary       4771 non-null   object
#  19  news_title         4771 non-null   object
#  20  news_topic         4771 non-null   object
#  21  news_type          4771 non-null   object
#  22  references         4268 non-null   object
#  23  sentiment_label    251 non-null    object
#  24  sentiment_score    4771 non-null   float64
#  25  source_country     4771 non-null   object
#  26  source_name        4771 non-null   object
#  27  source_type        4771 non-null   object
# dtypes: bool(1), float64(3), int64(1), object(23)
# memory usage: 1011.2+ KB

# %%
news_df = raw_df[['id', 'found_dates', 'news_date', 'news_title',
       'internal_links', 'keywords', 'language', 'news_author', 'news_content',
       'news_label', 'news_legalinforce',
       'news_link', 'news_rank', 'news_summary', 'news_topic',
       'news_type', 'sentiment_label', 'sentiment_score',
       'source_country', 'source_name', 'source_type']]

news_df.head(3)
# Out:
#                                id found_dates                 news_date  \
# 0  FinenfreiPresostenfrei12884764          []  2023-10-03T18:00:43.000Z
# 1    focScholzPresid217207826html          []  2023-10-03T16:59:33.000Z
# 2    merngnisPresente92556026html          []  2023-10-03T16:06:01.000Z
#
#                                           news_title internal_links keywords  \
# 0  Tradingaktion mit comdirect  Handeln Sie Socié...             []      NaN
# 1  CumExAffäre: Brisante Tagebucheinträge belaste...             []      NaN
# 2  CumExAffäre: Dokumente bringen Scholz offenbar...             []      NaN
#
#   language news_author                                       news_content  \
# 0       de         NaN  The article discusses how a fortunate man with...
# 1       en         NaN  The article discusses how M.M. Warburg may hav...
# 2       en         NaN  The Cologne Prosecutor's Office accuses German...
#
#   news_label  ...                                          news_link  \
# 0        NaN  ...  https://www.finanzen.net/nachricht/rohstoffe/t...
# 1        NaN  ...  https://www.focus.de/politik/staatsanwaltschaf...
# 2        NaN  ...  https://www.merkur.de/politik/scholz-cum-ex-af...
#
#   news_rank                                       news_summary  \
# 0         0  The article discusses how a fortunate man with...
# 1         0  The article discusses how M.M. Warburg may hav...
# 2         0  The Cologne Prosecutor's Office accuses German...
#
#                                           news_topic       news_type  \
# 0  [{"description":"Online Banken und Vermögensve...  Press releases
# 1  [{"description":"M.M. Warburg","relevance":12,...  Press releases
# 2  [{"description":"M.M. Warburg","relevance":6,"...  Press releases
#
#   sentiment_label sentiment_score  source_country   source_name  \
# 0             NaN             0.0         Germany  Finanzen.net
# 1             NaN             0.0          Global      focus.de
# 2             NaN             0.0          Global     merkur.de
#
#             source_type
# 0  Information Provider
# 1  Information Provider
# 2  Information Provider
#
# [3 rows x 21 columns]

# %%
news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4771 entries, 0 to 4770
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 4771 non-null   object
#  1   found_dates        4268 non-null   object
#  2   news_date          4771 non-null   object
#  3   news_title         4771 non-null   object
#  4   internal_links     4220 non-null   object
#  5   keywords           251 non-null    object
#  6   language           4768 non-null   object
#  7   news_author        85 non-null     object
#  8   news_content       4771 non-null   object
#  9   news_label         199 non-null    object
#  10  news_legalinforce  4771 non-null   bool
#  11  news_link          4771 non-null   object
#  12  news_rank          4771 non-null   int64
#  13  news_summary       4771 non-null   object
#  14  news_topic         4771 non-null   object
#  15  news_type          4771 non-null   object
#  16  sentiment_label    251 non-null    object
#  17  sentiment_score    4771 non-null   float64
#  18  source_country     4771 non-null   object
#  19  source_name        4771 non-null   object
#  20  source_type        4771 non-null   object
# dtypes: bool(1), float64(1), int64(1), object(18)
# memory usage: 750.3+ KB

# %%
news_df.language.hist()
# Out:
# <Axes: >

# %%
news_df_en = news_df[news_df.language == 'en']
print(len(news_df_en))
news_df_en.head(5)
# Out:
# 3105
#                               id found_dates                 news_date  \
# 1   focScholzPresid217207826html          []  2023-10-03T16:59:33.000Z
# 2   merngnisPresente92556026html          []  2023-10-03T16:06:01.000Z
# 3    maretBeatPresfiling20231003          []  2023-10-03T15:45:10.000Z
# 4  AlllationPres202310030398html          []  2023-10-03T15:40:05.000Z
# 5    busTIMESPresesginvestingubs          []  2023-10-03T15:35:31.000Z
#
#                                           news_title internal_links keywords  \
# 1  CumExAffäre: Brisante Tagebucheinträge belaste...             []      NaN
# 2  CumExAffäre: Dokumente bringen Scholz offenbar...             []      NaN
# 3  K.J. Harrison & Partners Inc Boosts Stake in C...             []      NaN
# 4    Mozambique: Govt Wins Massive Debt Cancellation             []      NaN
# 5  Conference aims to connect investors as ESG tr...             []      NaN
#
#   language news_author                                       news_content  \
# 1       en         NaN  The article discusses how M.M. Warburg may hav...
# 2       en         NaN  The Cologne Prosecutor's Office accuses German...
# 3       en         NaN  Deutsche Bank AG has acquired an additional 49...
# 4       en         NaN  Mozambique has reached a negotiated agreement ...
# 5       en         NaN  The UBS APAC Sustainable Finance Conference 20...
#
#   news_label  ...                                          news_link  \
# 1        NaN  ...  https://www.focus.de/politik/staatsanwaltschaf...
# 2        NaN  ...  https://www.merkur.de/politik/scholz-cum-ex-af...
# 3        NaN  ...  https://www.marketbeat.com/instant-alerts/nyse...
# 4        NaN  ...    https://allafrica.com/stories/202310030398.html
# 5        NaN  ...  https://www.businesstimes.com.sg/wealth/sustai...
#
#   news_rank                                       news_summary  \
# 1         0  The article discusses how M.M. Warburg may hav...
# 2         0  The Cologne Prosecutor's Office accuses German...
# 3         0  Deutsche Bank AG has acquired an additional 49...
# 4         0  Mozambique has reached a negotiated agreement ...
# 5         0  The UBS APAC Sustainable Finance Conference 20...
#
#                                           news_topic       news_type  \
# 1  [{"description":"M.M. Warburg","relevance":12,...  Press releases
# 2  [{"description":"M.M. Warburg","relevance":6,"...  Press releases
# 3  [{"description":"Deutsche Bank","relevance":6,...  Press releases
# 4  [{"description":"Financial Crime","relevance":...  Press releases
# 5  [{"description":"Sustainability","relevance":6...  Press releases
#
#   sentiment_label sentiment_score  source_country           source_name  \
# 1             NaN             0.0          Global              focus.de
# 2             NaN             0.0          Global             merkur.de
# 3             NaN             0.0          Global        marketbeat.com
# 4             NaN             0.0          Africa             AllAfrica
# 5             NaN             0.0          Global  businesstimes.com.sg
#
#             source_type
# 1  Information Provider
# 2  Information Provider
# 3  Information Provider
# 4  Information Provider
# 5  Information Provider
#
# [5 rows x 21 columns]

# %%
# sample news content and news summary

index = 2300

print(f"web_url: {news_df_en.news_link[index]}")
print(f"topic: {news_df_en.news_topic[index]}")
print(f"content: {news_df_en.news_content[index]}")
print(f"summary: {news_df_en.news_summary[index]}")
# Out:
# web_url: https://www.zonebourse.com/cours/action/KERING-4683/actualite-broker/Kering-Oddo-BHF-reste-a-neutre-avant-les-semestriels-44365621/
# topic: [{"description":"ODDO BHF","relevance":21,"comment":"; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; ; oddo bhf; ; "}]
# content: The article discusses the view of financial services company Oddo BHF on luxury goods company Kering ahead of its semi-annual results. Oddo BHF has maintained its neutral rating on Kering and has set a target price of \u20ac616. The analysis takes into account the potential impact of the COVID-19 pandemic on the luxury industry and highlights the uncertainties that lie ahead. While Kering's performance in the first quarter was strong, with revenue growth of 21.4%, concerns remain about the sustainability of this growth and the potential slowdown in the Chinese market. Oddo BHF emphasizes the importance of Kering's e-commerce strategy and the need for maintaining a balance between digital channels and physical retail locations. Overall, the article highlights the cautious stance of Oddo BHF regarding Kering's prospects in light of the evolving market conditions.
# summary: The article discusses the view of financial services company Oddo BHF on luxury goods company Kering ahead of its semi-annual results. Oddo BHF has maintained its neutral rating on Kering and has set a target price of \u20ac616. The analysis takes into account the potential impact of the COVID-19 pandemic on the luxury industry and highlights the uncertainties that lie ahead. While Kering's performance in the first quarter was strong, with revenue growth of 21.4%, concerns remain about the sustainability of this growth and the potential slowdown in the Chinese market. Oddo BHF emphasizes the importance of Kering's e-commerce strategy and the need for maintaining a balance between digital channels and physical retail locations. Overall, the article highlights the cautious stance of Oddo BHF regarding Kering's prospects in light of the evolving market conditions.

# %%
len(news_df_en[news_df_en.news_content == news_df_en.news_summary])
# almost all news summaries are same as news contents
# Out:
# 3032

# %%
# %pip install "accelerate>=0.16.0,<1" "transformers[torch]>=4.28.1,<5" "torch>=1.13.1,<2" "bitsandbytes>=0.40.2"
# Out:
# Collecting accelerate<1,>=0.16.0
#   Downloading accelerate-0.24.0-py3-none-any.whl (260 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 5.2 MB/s eta 0:00:00
# Collecting transformers[torch]<5,>=4.28.1
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 83.5 MB/s eta 0:00:00
# Collecting torch<2,>=1.13.1
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.8 MB/s eta 0:00:00
# Collecting bitsandbytes>=0.40.2
#   Downloading bitsandbytes-0.41.1-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate<1,>=0.16.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate<1,>=0.16.0) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate<1,>=0.16.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate<1,>=0.16.0) (6.0.1)
# Collecting huggingface-hub (from accelerate<1,>=0.16.0)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 31.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]<5,>=4.28.1) (3.12.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]<5,>=4.28.1) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]<5,>=4.28.1) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers[torch]<5,>=4.28.1)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 17.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers[torch]<5,>=4.28.1)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]<5,>=4.28.1) (4.66.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch<2,>=1.13.1) (4.5.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<2,>=1.13.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 44.3 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<2,>=1.13.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.1 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<2,>=1.13.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<2,>=1.13.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 80.7 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.13.1) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2,>=1.13.1) (0.41.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate<1,>=0.16.0) (2023.6.0)
# Collecting huggingface-hub (from accelerate<1,>=0.16.0)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 37.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]<5,>=4.28.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]<5,>=4.28.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]<5,>=4.28.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]<5,>=4.28.1) (2023.7.22)
# Installing collected packages: bitsandbytes, safetensors, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, huggingface-hub, torch, tokenizers, transformers, accelerate
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu118
#     Uninstalling torch-2.1.0+cu118:
#       Successfully uninstalled torch-2.1.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu118 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.16.0+cu118 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed accelerate-0.24.0 bitsandbytes-0.41.1 huggingface-hub-0.17.3 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 safetensors-0.4.0 tokenizers-0.14.1 torch-1.13.1 transformers-4.34.1

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    pipeline,
)

model_name="meta-llama/Llama-2-7b-chat-hf" # Model from hugging face
device_map = {"": 0} # Load the entire model on the GPU 0
use_4bit = True # Activate 4-bit precision base model loading
bnb_4bit_compute_dtype = "float16" # Compute dtype for 4-bit base models
bnb_4bit_quant_type = "nf4" # Quantization type (fp4 or nf4)
use_nested_quant = False # Activate nested quantization for 4-bit base models (double quantization)
compute_dtype = getattr(torch, bnb_4bit_compute_dtype) # Load tokenizer and model with QLoRA configuration

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
    )

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

#generate_text = pipeline(model="meta-llama/Llama-2-7b-chat-hf", torch_dtype=torch.bfloat16, trust_remote_code=True, device_map="auto")
#generate_text = pipeline(model=model, tokenizer=tokenizer, torch_dtype=torch.bfloat16, device_map="auto")
#generate_text = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=350)
generate_text = pipeline(task="text-generation", model=model, tokenizer=tokenizer, device_map="auto", torch_dtype=torch.bfloat16, max_length=256)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
res = generate_text("Explain to me the difference between nuclear fission and fusion.")
print(res[0]["generated_text"])
# Out:
# Explain to me the difference between nuclear fission and fusion. hopefully you can explain it in a way that is easy to understand.
# Nuclear fission is a process in which a heavy nucleus splits into two or more lighter nuclei, releasing energy in the process. This is the opposite of nuclear fusion, in which two or more lighter nuclei combine to form a heavier nucleus.
# Nuclear fission is the process by which an atomic nucleus splits into two or more smaller nuclei, releasing energy in the process. This is the opposite of nuclear fusion, in which two or more smaller nuclei combine to form a single, heavier nucleus.
# Nuclear fission is the process of splitting a heavy nucleus into two or more smaller nuclei, releasing energy in the process. Nuclear fusion is the process of combining two or more smaller nuclei to form a single, heavier nucleus, also releasing energy.
# Nuclear fission is the process of splitting a heavy nucleus into two or more smaller nuclei, releasing energy in the process. Nuclear fusion is the process of combining two or more smaller nuclei to

# %%
res = generate_text("'The article discusses the view of financial services company Oddo BHF on luxury goods company Kering ahead of its semi-annual results. Oddo BHF has maintained its neutral rating on Kering and has set a target price of \u20ac616. The analysis takes into account the potential impact of the COVID-19 pandemic on the luxury industry and highlights the uncertainties that lie ahead. While Kering's performance in the first quarter was strong, with revenue growth of 21.4%, concerns remain about the sustainability of this growth and the potential slowdown in the Chinese market. Oddo BHF emphasizes the importance of Kering's e-commerce strategy and the need for maintaining a balance between digital channels and physical retail locations. Overall, the article highlights the cautious stance of Oddo BHF regarding Kering's prospects in light of the evolving market conditions.' - What companies are being discussed in the text, just answer with the names of them (in order of importance) separated by commas.")
print(res[0]["generated_text"])
# Out:
# 'The article discusses the view of financial services company Oddo BHF on luxury goods company Kering ahead of its semi-annual results. Oddo BHF has maintained its neutral rating on Kering and has set a target price of €616. The analysis takes into account the potential impact of the COVID-19 pandemic on the luxury industry and highlights the uncertainties that lie ahead. While Kering's performance in the first quarter was strong, with revenue growth of 21.4%, concerns remain about the sustainability of this growth and the potential slowdown in the Chinese market. Oddo BHF emphasizes the importance of Kering's e-commerce strategy and the need for maintaining a balance between digital channels and physical retail locations. Overall, the article highlights the cautious stance of Oddo BHF regarding Kering's prospects in light of the evolving market conditions.' - What companies are being discussed in the text, just answer with the names of them (in order of importance) separated by commas.
#
# Kering, Oddo BHF.

# %%
news_df_en['llm_output_company'] = ""
news_df_en['companies_in_news'] = ""

max_prompt_length = 200
shortened_news_df = news_df_en[news_df_en['news_content'].apply(lambda x: len(x.split()) <= max_prompt_length)]
len(shortened_news_df)
# Out:
# <ipython-input-15-3f40701712ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_df_en['llm_output_company'] = ""
# <ipython-input-15-3f40701712ae>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_df_en['companies_in_news'] = ""
# 2888

# %%
# Filter out the specific warning
warnings.filterwarnings("ignore", category=UserWarning, module="transformers.pipelines.base")

for index, row in shortened_news_df.iterrows():
    prompt = "'" + row['news_content'] + "'" + " - What companies are being discussed in the text, just answer with the names of them (in order of importance) separated by commas. If there is only one company, do not use comma in your response."
    shortened_news_df.at[index, 'llm_output_company'] = generate_text(prompt)[0]["generated_text"]
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 303, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 402, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 258, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 441, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 313, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 284, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 264, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 270, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 276, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 266, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 267, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 265, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 281, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 269, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 478, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 456, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 462, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 442, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 257, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 344, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 485, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 461, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 260, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 412, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 338, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 458, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 331, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 302, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 280, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 272, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 426, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 291, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 380, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 292, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 289, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 283, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 288, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 279, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 299, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 268, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 263, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 286, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 297, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 341, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 312, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 273, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 262, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 304, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 256, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 382, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 581, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 275, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 259, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 1218, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 611, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 886, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 789, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 435, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 627, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 543, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1268: UserWarning: Input length of input_ids is 623, but `max_length` is set to 256. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   warnings.warn(

# %%
# Better code for last cell! ---> This fixes the warnings received in the previous cell.

# for index, row in shortened_news_df.iterrows():
#     prompt = "'" + row['news_content'] + "'" + " - What companies are being discussed in the text, just answer with the names of them (in order of importance) separated by commas. If there is only one company, do not use a comma in your response."
#     input_ids = tokenizer.encode(prompt, return_tensors='pt')
#     max_length = len(input_ids[0]) + 256  # Adjust the 256 according to your needs
#     shortened_news_df.at[index, 'llm_output_company'] = generate_text(prompt, max_length=max_length)[0]["generated_text"]

# %%
#extract company names from model output
for index, row in shortened_news_df.iterrows():
  split_text = row['llm_output_company'].split("What companies are being discussed in the text, just answer with the names of them (in order of importance) separated by commas. If there is only one company, do not use comma in your response.")
  if len(split_text) > 1:
    shortened_news_df.at[index, 'companies_in_news'] = split_text[1].strip()
  else:
    shortened_news_df.at[index, 'companies_in_news'] =  ""

# %%
# Save the DataFrame to a CSV file
shortened_news_df.to_csv('news_df_with_company_names.csv', index=False)

# Download the CSV file to your local machine
from google.colab import files
files.download('news_df_with_company_names.csv')

shortened_news_df[['news_content','companies_in_news']]
# Out:
#                                            news_content  \
# 1     The article discusses how M.M. Warburg may hav...
# 2     The Cologne Prosecutor's Office accuses German...
# 3     Deutsche Bank AG has acquired an additional 49...
# 4     Mozambique has reached a negotiated agreement ...
# 5     The UBS APAC Sustainable Finance Conference 20...
# ...                                                 ...
# 4763  DEUTSCHE BANK AG. DBK. Realtime Estimate Trade...
# 4764  DBN Deutsche Bank Ag 10.60 0.08decrease 0.75%d...
# 4765  Citigroup Inc. Deutsche Bank AG HSBC Holdings ...
# 4769  The Competition and Markets Authority said Cit...
# 4770  Follow the topics in this article. Gilts. Add ...
#
#                                       companies_in_news
# 1                             M.M. Warburg, The Scandal
# 2     Cologne, Prosecutor, Office, Olaf, Scholz, War...
# 3                           Deutsche Bank AG, Company A
# 4                        Mozambique, UBS, Credit Suisse
# 5                                                  UBS.
# ...                                                 ...
# 4763  Answer:\nDeutsche Bank AG, HSBC, Citi, Morgan ...
# 4764  The text discusses the following companies:\n\...
# 4765  Citigroup Inc, Deutsche Bank AG, HSBC Holdings...
# 4769  Citigroup Inc\nDeutsche Bank AG\nHSBC Holdings...
# 4770                           Gilts, Deutsche Bank AG.
#
# [2888 rows x 2 columns]

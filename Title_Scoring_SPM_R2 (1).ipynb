# %%
import pandas as pd

# %%
df = pd.read_csv("clustered_emails2_final.csv")

# %%
df
# Out:
#                                     campaign_title
# 0                 at_back_to_school_sale_2021sept8  \
# 1                       at_bf_broadcast1_2022oct28
# 2                       at_bf_broadcast4_2022nov17
# 3                       at_bf_broadcast7_2022nov10
# 4                        at_bf_broadcast_2022nov07
# ..                                             ...
# 127  ch_blackfridaysale_newsletter4_2021november27
# 128  ch_blackfridaysale_newsletter5_2021november29
# 129          ch_black_weeks_private_sale_2021nov03
# 130                 ch_carnivalsale23_#1_2023feb16
# 131               ch_christmasemail_2021december24
#
#                                               textdata  openrate  clickrate
# 0    Spare bis zu 695€! BACK TO SCHOOL mit bestem S...    0.5434     0.1314  \
# 1    Die Emma Black Weeks sind da: Spare bis zu 50%...    0.3759     0.0705
# 2    Emma Black Weeks: Sichere Dir bis zu 50% +extr...    0.6245     0.0802
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame 'df' with 'text_data' and 'cluster' columns
# Replace 'df' with your DataFrame name

# Initialize an empty dictionary to store merged text data for each cluster
merged_clusters = {}

# Iterate through unique cluster labels
unique_clusters = df['cluster'].unique()
for cluster_label in unique_clusters:
    # Filter the DataFrame for rows with the current cluster label
    cluster_df = df[df['cluster'] == cluster_label]
    
    # Merge the text data within the cluster into a single string
    merged_text = ' '.join(cluster_df['textdata'])
    
    # Store the merged text data in the dictionary with the cluster label as the key
    merged_clusters[cluster_label] = merged_text

# Now 'merged_clusters' contains merged text data for each cluster
# You can access the merged text for a specific cluster using its label
# For example, to access the merged text for cluster 0:
cluster_0_text = merged_clusters[0]

# To access the merged text for cluster 1:
cluster_1_text = merged_clusters[1]

# And so on for other clusters

# %%
# To access the merged text for cluster 1:
cluster_2_text = merged_clusters[2]
cluster_2_text
# Out:
# 'Neujahrsvorsatz: Besser schlafen in 2023 😴 Mit erholsamen Schlaf das Beste aus dem neuen Jahr machen! Sichere dir 5% extra Rabatt mit dem Code EMMAPLUS 5 Mit erholsamen Schlaf das Beste aus dem neuen Jahr machen! Sparen, Abnehmen, mit dem Rauchen aufhören, eine gesunde Ernährung, weniger Zeit auf Social Media verbringen, mehr Sport treiben , sind statistisch die häufigsten Neujahrsvorsätze. Aber wie wäre es mal mit besser schlafen? Emma hilft dir sogar mit deinem diesjährigen Neujahrsvorsatz, besser zu schlafen und hat noch ein Geschenk für dich: Nur für dich 5% extra Rabatt auf alle Kategorien! EMMAPLUS 5 Neujahrsvorsatz umsetzen Emma - Jeden Morgen Dein bestes Ich 10 Jahre Garantie 100 Nächte Probeschlafen Kostenlose Lieferung und Abholung Emma Matratzen GmbH Webseite | Impressum | Meine Einstellungen aktualisieren | Abmelden Jetzt schnell sein! Unsere Neuheit gratis testen Besserer Schlaf mit der Emma Up App Finde heraus wieso du dich tagsüber schläfrig fühlst & folge unserem Sch
# ...

# %%
import pandas as pd
import openai

# Set your OpenAI API key
api_key = "Your API KEY"

# Initialize the OpenAI API client
openai.api_key = api_key

# Assuming you have a DataFrame 'df' with 'text_data' and 'cluster' columns
# Replace 'df' with your DataFrame name

# Initialize an empty dictionary to store merged text data and headings for each cluster
cluster_headings = {}

# Iterate through unique cluster labels
unique_clusters = df['cluster'].unique()
for cluster_label in unique_clusters:
    # Filter the DataFrame for rows with the current cluster label
    cluster_df = df[df['cluster'] == cluster_label]
    
    # Merge the text data within the cluster into a single string
    merged_text = ' '.join(cluster_df['textdata'])  # Update to 'textdata'
    
    # Use the OpenAI GPT-3 model for text summarization with the chat endpoint
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "Please provide a defination for the following text."},
            {"role": "user", "content": merged_text},
        ],
        max_tokens=150,  # Adjust the length of the heading as needed
    )

    # Extract the generated heading from the response
    cluster_heading = response.choices[0].message["content"].strip()  # Update to 'heading'
    
    # Store the merged text data and heading in the dictionary with the cluster label as the key
    cluster_headings[cluster_label] = {
        'merged_text': merged_text,
        'heading': cluster_heading  # Update to 'heading'
    }

# Now 'cluster_headings' contains merged text data and headings for each cluster
# You can access the merged text data and heading for a specific cluster using its label
# For example, to access the merged text data and heading for cluster 0:
cluster_0_data = cluster_headings[0]
cluster_0_merged_text = cluster_0_data['merged_text']
cluster_0_heading = cluster_0_data['heading']  # Update to 'heading'

# To access the merged text data and heading for cluster 1:
cluster_1_data = cluster_headings[1]
cluster_1_merged_text = cluster_1_data['merged_text']
cluster_1_heading = cluster_1_data['heading']  # Update to 'heading'

# And so on for other clusters

# %%
cluster_2_data = cluster_headings[2]
cluster_2_merged_text = cluster_2_data['merged_text']
cluster_2_heading = cluster_2_data['heading']  # Update to 'heading'

# To access the merged text data and summary for cluster 1:
cluster_3_data = cluster_headings[3]
cluster_3_merged_text = cluster_3_data['merged_text']
cluster_3_heading = cluster_3_data['heading']  # Update to 'heading'

# To access the merged text data and summary for cluster 1:
cluster_4_data = cluster_headings[4]
cluster_4_merged_text = cluster_4_data['merged_text']
cluster_4_heading = cluster_4_data['heading']  # Update to 'heading'

# %%
cluster_0_heading,cluster_1_heading,cluster_2_heading,cluster_3_heading,cluster_4_heading
# Out:
# ('Die besten Materialien für eine erholsame Nacht',
#  'Winter Sale: Bis zu 62% Rabatt auf unsere Schlafprodukte! Sichere dir jetzt die besten Angebote für erholsamen Schlaf.',
#  'Tipps für einen besseren Schlaf',
#  'Erhalte ein gratis Kissen und teile uns deine Erfahrung mit! 🎁',
#  '"Emma Black Friday Sale: Bis zu 50% Rabatt auf hochwertige Schlafprodukte!"')

# %% [markdown]
# # Providing Headings to Definations

# %%
cluster_summaries
# Out:
# {1: {'merged_text': 'Spare bis zu 695€! BACK TO SCHOOL mit bestem Schlaf durch unsere Schlafprodukte! Ob Studentenbude, Kinderzimmer oder sonst ein Schlafzimmer - Jeder sollte erholt schlafen, um maximale Leistung zu erbringen. Deshalb gibt es bei uns pünktlich zum Schul- und Semesterstart bis zu 40% Rabatt! So kann jeder mit voller Kraft in den Tag starten! Jetzt sparen! Alle Rabatte sind direkt auf unserer Website ersichtlich und nicht mit anderen Rabattaktionen kombinierbar. 100 Nächte Probeschlafen Kostenlose Lieferung und Abholung 10 Jahre Garantie Emma Matratzen GmbH Wilhelm-Leuschner-Str. 78 60329 Frankfurt Am Main Website | Impressum | Unsubscribe ID number: 04522940020 | Tax ID: DE301904406 🖤Bis zu 50% Rabatt auf unserer gesamten Website🖤 Draußen mag es kalt sein, aber unsere Preise sind heiß! Draußen mag es kalt sein, aber unsere Preise sind heiß! Um deine Winterkraft zu stärken, erhältst du all unsere Betten mit unschlagbaren Rabatten. Jetzt entdecken DIESE WOCHE EMPFEHLEN
# ...

# %%
import pandas as pd
import openai

# Set your OpenAI API key
api_key = "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"

# Initialize the OpenAI API client
openai.api_key = api_key

# Assuming you have a DataFrame 'df' with 'text_data' and 'cluster' columns
# Replace 'df' with your DataFrame name

# Initialize an empty dictionary to store merged text data and summaries for each cluster
heading_summaries = {}

# Iterate through unique cluster labels
heading_clusters = df['cluster'].unique()
for cluster_label in heading_clusters:
    # Filter the DataFrame for rows with the current cluster label
    cluster_df = df[df['cluster'] == cluster_label]
    
    # Merge the text data within the cluster into a single string
    merged_text = ' '.join(cluster_df['text_data'])
    
    # Use the OpenAI GPT-3 model for text summarization with the chat endpoint
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "Please provide a heading for the following text."},
            {"role": "user", "content": merged_text},
        ],
        max_tokens=150,  # Adjust the length of the summary as needed
    )

    # Extract the generated summary from the response
    cluster_summary = response.choices[0].message["content"].strip()
    
    # Store the merged text data and summary in the dictionary with the cluster label as the key
    heading_summaries[cluster_label] = {
        'merged_text': merged_text,
        'heading': cluster_summary
    }

# Now 'heading_summaries' contains merged text data and summaries for each cluster
# You can access the merged text data and summary for a specific cluster using its label
# For example, to access the merged text data and summary for cluster 0:
heading_0_data = heading_summaries[0]
heading_0_merged_text = heading_0_data['merged_text']
heading_0_summary = heading_0_data['heading']

heading_1_data = heading_summaries[1]
heading_1_merged_text = heading_1_data['merged_text']
heading_1_summary = heading_1_data['heading']

# Repeat the above pattern for other clusters as needed
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text_data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd
import openai

# Set your OpenAI API key
api_key =  OpenAI API key
api_key = "Your API KEY"

# Initialize the OpenAI API client
openai.api_key = api_key

# Assuming you have a DataFrame 'df' with 'text_data' and 'cluster' columns
# Replace 'df' with your DataFrame name

# Initialize an empty dictionary to store merged text data and summaries for each cluster
heading_summaries = {}

# Iterate through unique cluster labels
heading_clusters = df['cluster'].unique()
for cluster_label in heading_clusters:
    # Filter the DataFrame for rows with the current cluster label
    cluster_df = df[df['cluster'] == cluster_label]
    
    # Merge the text data within the cluster into a single string
    merged_text = ' '.join(cluster_df['textdata'])
    
    # Use the OpenAI GPT-3 model for text summarization with the chat endpoint
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "Please provide a heading for the following text."},
            {"role": "user", "content": merged_text},
        ],
        max_tokens=150,  # Adjust the length of the summary as needed
    )

    # Extract the generated summary from the response
    heading_summaries = response.choices[0].message["content"].strip()
    
    # Store the merged text data and summary in the dictionary with the cluster label as the key
    heading_summaries[cluster_label] = {
        'merged_text': merged_text,
        'heading': cluster_summary
    }

# Now 'cluster_summaries' contains merged text data and summaries for each cluster
# You can access the merged text data and summary for a specific cluster using its label
# For example, to access the merged text data and summary for cluster 0:
heading_0_data = heading_summaries[0]
heading_0_merged_text = heading_0_data['merged_text']
heading_0_summary = heading_0_data['heading']

heading_1_data = heading_summaries[1]
heading_1_merged_text = heading_1_data['merged_text']
heading_1_summary = heading_1_data['heading']

heading_2_data = heading_summaries[2]
heading_2_merged_text = heading_2_data['merged_text']
heading_2_summary = heading_2_data['heading']

heading_3_data = heading_summaries[3]
heading_3_merged_text = heading_3_data['merged_text']
heading_3_summary = heading_3_data['heading']

heading_4_data = heading_summaries[4]
heading_4_merged_text = heading_4_data['merged_text']
heading_4_summary = heading_4_data['heading']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 18>()
#      36     heading_summaries = response.choices[0].message["content"].strip()
#      38     # Store the merged text data and summary in the dictionary with the cluster label as the key
# ---> 39     heading_summaries[cluster_label] = {
#      40         'merged_text': merged_text,
#      41         'heading': cluster_summary
#      42     }
#      44 # Now 'cluster_summaries' contains merged text data and summaries for each cluster
#      45 # You can access the merged text data and summary for a specific cluster using its label
#      46 # For example, to access the merged text data and summary for cluster 0:
#      47 heading_0_data = heading_summaries[0]
#
# TypeError: 'str' object does not support item assignment

# %%
heading_1 = response.choices[1].text.strip()
summary_headings[summary] = heading_1

#
heading_2 = response.choices[2].text.strip()
summary_headings[summary] = heading_2
#
heading_3 = response.choices[3].text.strip()
summary_headings[summary] = heading_3
#
heading_4 = response.choices[4].text.strip()
summary_headings[summary] = heading_4
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 heading_1 = response.choices[1].text.strip()
#       2 summary_headings_1[summary] = heading_1
#       4 #
#
# IndexError: list index out of range

# %%
summary_headings[summary][1]
# Out:
# 'u'

# %%
for cluster_label in unique_clusters:
    # Filter the DataFrame for rows with the current cluster label
    cluster_df = df[df['cluster'] == cluster_label]
    
    # Merge the text data within the cluster into a single string
    merged_text = ' '.join(cluster_df['textdata'])
    
    # Use the OpenAI GPT-3 model for text summarization with the chat endpoint
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "Please provide a definition for the following text."},
            {"role": "user", "content": merged_text},
        ],
        max_tokens=150,  # Adjust the length of the summary as needed
    )

    # Extract the generated summary from the response
    cluster_summary = response.choices[0].message["content"].strip()
    
    # Store the merged text data and summary in the dictionary with the cluster label as the key
    cluster_summaries[cluster_label] = {
        'merged_text': merged_text,
        'summary': cluster_summary
    }

# %%
cluster_1_summary
# Out:
# 'Winterzeit ist Rabattzeit bei Emma! Spare bis zu 695€ auf unsere Schlafprodukte für erholsamen Schlaf und maximale Leistung.'

# %%
cluster_0_summary
# Out:
# '"Die besten Materialien für erholsamen Schlaf: Entdecke die hochwertigen Emma Produkte"'

# %%
from sklearn.cluster import KMeans
import pandas as pd
import openai

# Set your OpenAI API key
api_key =  OpenAI API key
api_key = "Your API KEY"

# Initialize the OpenAI API client
openai.api_key = api_key

# Load your text data and cluster assignments
# Replace these with your own data  # List of your text data

# Number of clusters (replace with your desired number)
num_clusters = 5

# Perform K-Means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(your_text_data)

# Create a DataFrame with text data and cluster assignments
data = {'text': your_text_data, 'cluster': cluster_labels}
df = pd.DataFrame(data)

# Generate topics for each cluster
cluster_topics = []

for cluster_id in range(num_clusters):
    cluster_text = df[df['cluster'] == cluster_id]['text'].tolist()

    # Concatenate the cluster text
    cluster_text = " ".join(cluster_text)

    # Use the OpenAI GPT-3 model for text summarization
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=cluster_text,
        max_tokens=100,  # Adjust the length of the summary as needed
        n=1,  # Number of summaries to generate
    )

    # Extract the generated summary from the response
    cluster_summary = response.choices[0].text.strip()
    cluster_topics.append(cluster_summary)

# Print or store the generated topics for each cluster
for cluster_id, topic in enumerate(cluster_topics):
    print(f"Cluster {cluster_id} Topic:")
    print(topic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 19>()
#      17 # Perform K-Means clustering
#      18 kmeans = KMeans(n_clusters=num_clusters, random_state=42)
# ---> 19 cluster_labels = kmeans.fit_predict(your_text_data)
#      21 # Create a DataFrame with text data and cluster assignments
#      22 data = {'text': your_text_data, 'cluster': cluster_labels}
#
# File ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1033, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1010 def fit_predict(self, X, y=None, sample_weight=None):
#    1011     """Compute cluster centers and predict cluster index for each sample.
#    1012
#    1013     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#    1031         Index of the cluster each sample belongs to.
#    1032     """
# ...
